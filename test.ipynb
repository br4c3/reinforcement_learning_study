# %%
# !mkdir src
# Out:
# mkdir: src: File exists

# %%
# %%writefile src/test.py

def printHello():
    print("hello")
# Out:
# Overwriting src/test.py

# %%
# %%writefile src/__init__.py
__all__ = ["printHello"]
from test import printHello

# %%
# !python3 test.py
# Out:
# hello

# %%
from src import printHello

printHello()
# Out:
# hello
